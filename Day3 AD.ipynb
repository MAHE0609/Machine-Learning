# %%
h=(90,70,50,30,20,50,30,10,50,20,20,20,90,80,60,60,60,60)
h
# Out:
# (90, 70, 50, 30, 20, 50, 30, 10, 50, 20, 20, 20, 90, 80, 60, 60, 60, 60)

# %%
type(h)
# Out:
# tuple

# %%
h.count(60)
# Out:
# 4

# %%
h.index(60)
# Out:
# 14

# %%
h.count(20)
# Out:
# 4

# %%
h[3]
# Out:
# 30

# %%
h[0]
# Out:
# 90

# %%
h[0:3]
# Out:
# (90, 70, 50)

# %%
s={80,70,30,80,60,30,10,20}
s
# Out:
# {10, 20, 30, 60, 70, 80}

# %%
type(s)
# Out:
# set

# %%
s.add(90)
s
# Out:
# {10, 20, 30, 60, 70, 80, 90}

# %%
s.remove(80)
s
# Out:
# {10, 20, 30, 60, 70, 90}

# %%
y={40,30,60,20,90,10}
y
# Out:
# {10, 20, 30, 40, 60, 90}

# %%
s.intersection(y)
# Out:
# {10, 20, 30, 60, 90}

# %%
s.union(y)
# Out:
# {10, 20, 30, 40, 60, 70, 90}

# %%
s.difference(y)
# Out:
# {70}

# %%
y.difference(s)
# Out:
# {40}

# %%
s.symmetric_difference(y)
# Out:
# {40, 70}

# %%
y.symmetric_difference(s)
# Out:
# {40, 70}

# %%
y={40,30,60,20,90,10}
y
# Out:
# {10, 20, 30, 40, 60, 90}

# %%
tuple(y)
# Out:
# (20, 90, 40, 10, 60, 30)

# %%
list(y)
# Out:
# [20, 90, 40, 10, 60, 30]
